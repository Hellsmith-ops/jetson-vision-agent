# %% [markdown]
# Goal: run checks on dependencies and packages

# %%
import platform
import torch
import cv2
import os

print("===== SYSTEM =====")
print("Python:", platform.python_version())

print("\n===== TORCH =====")
print("Torch Version:", torch.__version__)
print("CUDA Available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

print("\n===== OPENCV =====")
print("OpenCV:", cv2.__version__)

print("\n===== WORKSPACE =====")
print(os.getcwd())
# Out:
# ===== SYSTEM =====
# Python: 3.12.3
#
# ===== TORCH =====
# Torch Version: 2.7.0
# CUDA Available: True
# GPU: Orin
#
# ===== OPENCV =====
# OpenCV: 4.13.0
#
# ===== WORKSPACE =====
# /workspace/notebooks

# %%
import torch
import time

print("Running GPU test...")

x = torch.rand((3000,3000),device='cuda')

start=time.time()

for i in range(100):
    y=x@x

print("Elapsed:",time.time()-start)
# Out:
# Running GPU test...
# Elapsed: 0.09339523315429688
