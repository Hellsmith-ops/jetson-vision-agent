# %% [markdown]
# Goal: verify Jetson camera access.

# %%
import cv2

cam=cv2.VideoCapture(0)

ret,frame=cam.read()

print(ret)

cam.release()
# Out:
# True

# %%
import matplotlib.pyplot as plt

plt.imshow(
    cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
)
