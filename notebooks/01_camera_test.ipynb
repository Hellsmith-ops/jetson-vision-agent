# %% [markdown]
# ## Goal: verify Jetson camera access.

# %% [markdown]
# 1. Confirm that Jetson has access to camera and can use it.

# %%
import cv2

cam = cv2.VideoCapture(0, cv2.CAP_V4L2)
print("Camera opened:", cam.isOpened())

time.sleep(2)

for i in range(30):
    ret, frame = cam.read()

print("Frame captured:", ret)
print("Frame shape:", frame.shape if ret else None)

cam.release()
# Out:
# Camera opened: True
# Frame captured: True
# Frame shape: (480, 640, 3)

# %% [markdown]
# 2. Capture an example frame

# %%
import matplotlib.pyplot as plt

if ret:
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    plt.imshow(frame_rgb)
    plt.axis("off")
    plt.show()

# %% [markdown]
# Jetson now has access to camera.
